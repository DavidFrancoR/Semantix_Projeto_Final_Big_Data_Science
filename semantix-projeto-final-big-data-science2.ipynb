# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
plt.rcParams['figure.figsize'] = (17, 10) # Tamanho das figuras em Polegadas 
plt.rcParams['axes.titlepad'] = 30 # Padding do Titulo

# %%
sns.set_palette("Accent") # Paleta de Cores 
sns.set_style("whitegrid") # Estilo de gráficos
sns.set(font_scale=1.5) # Configurando o tamanho da fonte

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x) # Formatando para  1000000.00 por exemplo

# %%
#data_path = "/content/drive/MyDrive/Semantix_Projeto_Final_Big_Data_Science/microdados_enem_2019/DADOS/MICRODADOS_ENEM_2019.csv"
# https://www.kaggle.com/saraivaufc/enem-2019
# ../input/microdados-enem-2019
data_path = "../input/microdados-enem-2019/DADOS/MICRODADOS_ENEM_2019.csv"
df1 = pd.read_csv(data_path, sep=';', encoding = "ISO-8859-1", chunksize=1000000)

df1 = pd.concat(df1, ignore_index=True)
# 29 bahia  CO_UF_RESIDENCIA
#surveys_df[surveys_df.year == 2002]
#df[df.CO_UF_RESIDENCIA == 29]
df1.head()

# %%
#df[df.CO_UF_RESIDENCIA == 29]
#df.head()
dfba = df1['CO_UF_RESIDENCIA'] == 29
dfba.head()

# %%
df = df1[dfba]
df.head()

# %%
df

# %%
df.shape

# %%
df.columns()

# %%
df.describe()

# %%
data_crosstab = pd.crosstab(df['NO_MUNICIPIO_RESIDENCIA'],  
                            df['TP_SEXO'], 
                                margins = False) 
print(data_crosstab)

# %%
(df.TP_SEXO.value_counts() *100)/ df.TP_SEXO.count()

# %%
enem_por_sexo = df.TP_SEXO.value_counts() # Contabilizamos os registros por cada sexo.

_, ax = plt.subplots() # Criamos a figura onde exibiremos o Gráfico

patches, texts, autotexts = ax.pie( # configuramos o gráfico de Pizza.
    enem_por_sexo, 
    colors = ['red','blue'], 
    labels=['Feminino', 'Masculino'], 
    autopct='%1.1f%%', 
    startangle=90
)
for text in texts:
    text.set_color('black')
for autotext in autotexts:
    autotext.set_color('white')
    
plt.title('Inscrições por Sexo  [ENEM 2019]');

# %%
sns.boxplot(df.NU_IDADE);

# %%
sns.boxplot(df.NU_IDADE, color='tab:blue') # Criando o gráfico de Boxplot para as idades

plt.xlabel('Idades') # Rótulo do Eixo X
plt.title('Boxplot das Idades - [ENEM 2019]');

# %%
df.NU_IDADE.hist();

# %%
sns.histplot(df.NU_IDADE, bins=50) # Bins é quantidade de barras possiveis.

plt.yticks(
    ticks=[0, 20000, 40000, 60000, 80000, 100000, 120000, 140000],
    labels=['0', '20K', '40K', '60K', '80K', '100K', '120K', '140K']
) # Valores presentes no eixo y

plt.xticks(range(0, 91, 5)) # Valores presentes no eixo X


plt.ylabel("Quantidade de Inscritos") # Nome do Eixo  Vertical
plt.xlabel("Idades") # Nome do Eixo Horizontal

plt.title("Distribuição das Idades - [ENEM 2019]"); # Titulo do gráfico

# %%
media_idades = df.NU_IDADE.mean() # Calculando a média das idades 
sns.histplot(df.NU_IDADE, bins=50) # Bins é quantidade de barras possiveis.

plt.yticks(
#    ticks=[0, 200000, 400000, 600000, 800000, 1000000, 1200000, 1400000],
#    labels=['0', '200K', '400K', '600K', '800K', '1M', '1.2M', '1.4M']
    ticks=[0, 20000, 40000, 60000, 80000, 100000, 120000, 140000],
    labels=['0', '20K', '40K', '60K', '80K', '100K', '120K', '140K']


) # Valores presentes no eixo y

plt.xticks(range(0, 91, 5)) # Valores presentes no eixo X
plt.axvline(media_idades, c='red', label='Média das idades {}'.format(round(media_idades,0))) #linha horizontal com a média

plt.ylabel("Quantidade de Inscritos") # Nome do Eixo  Vertical
plt.xlabel("Idades") # Nome do Eixo Horizontal

plt.title("Distribuição das Idades - [ENEM 2019]") # Titulo do gráfico
plt.legend()

# %%
df.TP_SEXO.hist();

# %%
df_visualizacao = df.groupby(by=['TP_ESTADO_CIVIL']).count()['NU_INSCRICAO'].reset_index()
df_visualizacao

# %%
df.TP_ESTADO_CIVIL1 = df.TP_ESTADO_CIVIL.replace({0: "Não informado", 1: "Solteiro(a)", 2: "Casado(a)/Mora com companheiro(a)", 3: "Divorciado(a)/Desquitado(a)/Separado(a)", 4: "Viúvo(a)"})

# %%
df.TP_COR_RACA = df.TP_COR_RACA.replace({0: "Não declarado", 1: "Branca", 2: "Preta", 3: "Parda", 4: "Amarela", 5: "Indígena"})

# %%
df_visualizacaor = df.groupby(by=['TP_COR_RACA']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaor

# %%
df.TP_NACIONALIDADE = df.TP_NACIONALIDADE.replace({0: "Não informado", 1: "Brasileiro(a)", 2: "Brasileiro(a) Naturalizado(a)", 3: "Estrangeiro(a)", 4: "Brasileiro(a) Nato(a), nascido(a) no exterior"})

# %%
df_visualizacaoN = df.groupby(by=['TP_NACIONALIDADE']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoN

# %%
df.TP_ST_CONCLUSAO = df.TP_ST_CONCLUSAO.replace({1: "Já concluí o Ensino Médio", 2: "Estou cursando e concluirei o Ensino Médio em 2019", 3: "Estou cursando e concluirei o Ensino Médio após 2019", 4: "Não concluí e não estou cursando o Ensino Médio"})

# %%
df_visualizacaoC = df.groupby(by=['TP_ST_CONCLUSAO']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoC

# %%
df.TP_ANO_CONCLUIU = df.TP_ANO_CONCLUIU.replace({0: "Não informado", 1: "2018", 2: "2017", 3: "2016", 4: "2015", 5: "2014", 6: "2013", 7: "2012", 8: "2011", 9: "2010", 10: "2009", 11: "2008", 12: "2007", 13: "Antes de 2007"})

# %%
df_visualizacaoA = df.groupby(by=['TP_ANO_CONCLUIU']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoA

# %%
df.TP_ESCOLA = df.TP_ESCOLA.replace({1: "Não Respondeu", 2: "Pública", 3: "Privada", 4: "Exterior"})

# %%
df_visualizacaoE = df.groupby(by=['TP_ESCOLA']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoE

# %%
df.TP_ENSINO = df.TP_ENSINO.replace({1: "Ensino Regular", 2: "Educação Especial - Modalidade Substitutiva", 3: "Educação de Jovens e Adultos"})

# %%
df_visualizacaoEN = df.groupby(by=['TP_ENSINO']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoEN

# %%
df.IN_TREINEIRO = df.IN_TREINEIRO.replace({1: "Sim", 0: "Não"})

# %%
df_visualizacaoT = df.groupby(by=['IN_TREINEIRO']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoT

# %%
df.TP_STATUS_REDACAO = df.TP_STATUS_REDACAO.replace({1: "Sem problemas", 2: "Anulada", 3: "Cópia Texto Motivador", 4: "Em Branco", 6: "Fuga ao tema", 7: "Não atendimento ao tipo textual", 8: "Texto insuficiente", 9: "Parte desconectada"})

# %%
df_visualizacaoCO = df.groupby(by=['TP_STATUS_REDACAO']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoCO

# %%
df.Q001 = df.Q001.replace({"A": "Nunca estudou.", "B": "Não completou a 4ª série/5º ano do Ensino Fundamental.", "C": "Completou a 4ª série/5º ano, mas não completou a 8ª série/9º ano do Ensino Fundamental.", "D": "Completou a 8ª série/9º ano do Ensino Fundamental, mas não completou o Ensino Médio.", "E": "Completou o Ensino Médio, mas não completou a Faculdade.", "F": "Completou a Faculdade, mas não completou a Pós-graduação.", "G": "Completou a Pós-graduação.", "H": "Não sei."})

# %%
df_visualizacaoQ1 = df.groupby(by=['Q001']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ1

# %%
df.Q002 = df.Q002.replace({"A": "Nunca estudou.", "B": "Não completou a 4ª série/5º ano do Ensino Fundamental.", "C": "Completou a 4ª série/5º ano, mas não completou a 8ª série/9º ano do Ensino Fundamental.", "D": "Completou a 8ª série/9º ano do Ensino Fundamental, mas não completou o Ensino Médio.", "E": "Completou o Ensino Médio, mas não completou a Faculdade.", "F": "Completou a Faculdade, mas não completou a Pós-graduação.", "G": "Completou a Pós-graduação.", "H": "Não sei."})

# %%
df_visualizacaoQ2 = df.groupby(by=['Q002']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ2

# %%
df.Q003 = df.Q003.replace({"A": "Grupo 1: Lavrador, agricultor sem empregados, bóia fria, criador de animais (gado, porcos, galinhas, ovelhas, cavalos etc.), apicultor, pescador, lenhador, seringueiro, extrativista.", "B": "Grupo 2: Diarista, empregado doméstico, cuidador de idosos, babá, cozinheiro (em casas particulares), motorista particular, jardineiro, faxineiro de empresas e prédios, vigilante, porteiro, carteiro, office-boy, vendedor, caixa, atendente de loja, auxiliar administrativo, recepcionista, servente de pedreiro, repositor de mercadoria.", "C": "Grupo 3: Padeiro, cozinheiro industrial ou em restaurantes, sapateiro, costureiro, joalheiro, torneiro mecânico, operador de máquinas, soldador, operário de fábrica, trabalhador da mineração, pedreiro, pintor, eletricista, encanador, motorista, caminhoneiro, taxista.", "D": "Grupo 4: Professor (de ensino fundamental ou médio, idioma, música, artes etc.), técnico (de enfermagem, contabilidade, eletrônica etc.), policial, militar de baixa patente (soldado, cabo, sargento), corretor de imóveis, supervisor, gerente, mestre de obras, pastor, microempresário (proprietário de empresa com menos de 10 empregados), pequeno comerciante, pequeno proprietário de terras, trabalhador autônomo ou por conta própria.", "E": "Grupo 5: Médico, engenheiro, dentista, psicólogo, economista, advogado, juiz, promotor, defensor, delegado, tenente, capitão, coronel, professor universitário, diretor em empresas públicas ou privadas, político, proprietário de empresas com mais de 10 empregados.", "F": "Não sei."})

# %%
df_visualizacaoQ3 = df.groupby(by=['Q003']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ3

# %%
df.Q004 = df.Q004.replace({"A": "Grupo 1: Lavradora, agricultora sem empregados, bóia fria, criadora de animais (gado, porcos, galinhas, ovelhas, cavalos etc.), apicultora, pescadora, lenhadora, seringueira, extrativista.", "B": "Grupo 2: Diarista, empregada doméstica, cuidadora de idosos, babá, cozinheira (em casas particulares), motorista particular, jardineira, faxineira de empresas e prédios, vigilante, porteira, carteira, office-boy, vendedora, caixa, atendente de loja, auxiliar administrativa, recepcionista, servente de pedreiro, repositora de mercadoria.", "C": "Grupo 3: Padeira, cozinheira industrial ou em restaurantes, sapateira, costureira, joalheira, torneira mecânica, operadora de máquinas, soldadora, operária de fábrica, trabalhadora da mineração, pedreira, pintora, eletricista, encanadora, motorista, caminhoneira, taxista.", "D": "Grupo 4: Professora (de ensino fundamental ou médio, idioma, música, artes etc.), técnica (de enfermagem, contabilidade, eletrônica etc.), policial, militar de baixa patente (soldado, cabo, sargento), corretora de imóveis, supervisora, gerente, mestre de obras, pastora, microempresária (proprietária de empresa com menos de 10 empregados), pequena comerciante, pequena proprietária de terras, trabalhadora autônoma ou por conta própria.", "E": "Grupo 5: Médica, engenheira, dentista, psicóloga, economista, advogada, juíza, promotora, defensora, delegada, tenente, capitã, coronel, professora universitária, diretora em empresas públicas ou privadas, política, proprietária de empresas com mais de 10 empregados.", "F": "Não sei."})

# %%
df_visualizacaoQ4 = df.groupby(by=['Q004']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ4

# %%
df.Q005 = df.Q005.replace({1: "1, pois moro sozinho(a)." })

# %%
df_visualizacaoQ5 = df.groupby(by=['Q005']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ5

# %%
df.Q006 = df.Q006.replace({"A": "Nenhuma renda.", "B": "Até R$ 998,00.", "C": "De R$ 998,01 até R$ 1.497,00.", "D": "De R$ 1.497,01 até R$ 1.996,00.", "E": "De R$ 1.996,01 até R$ 2.495,00.", "F": "De R$ 2.495,01 até R$ 2.994,00.", "G": "De R$ 2.994,01 até R$ 3.992,00.", "H": "De R$ 3.992,01 até R$ 4.990,00.", "I": "De R$ 4.990,01 até R$ 5.988,00.", "J": "De R$ 5.988,01 até R$ 6.986,00.", "K": "De R$ 6.986,01 até R$ 7.984,00.", "L": "De R$ 7.984,01 até R$ 8.982,00.", "M": "De R$ 8.982,01 até R$ 9.980,00.", "N": "De R$ 9.980,01 até R$ 11.976,00.", "O": "De R$ 11.976,01 até R$ 14.970,00.", "P": "De R$ 14.970,01 até R$ 19.960,00.", "Q": "Mais de R$ 19.960,00."})

# %%
df_visualizacaoQ6 = df.groupby(by=['Q006']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ6

# %%
df.Q007 = df.Q007.replace({"A": "Não.", "B": "Sim, um ou dois dias por semana.", "C": "Sim, três ou quatro dias por semana.", "D": "Sim, pelo menos cinco dias por semana."})

# %%
df_visualizacaoQ7 = df.groupby(by=['Q007']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ7

# %%
df.Q008 = df.Q008.replace({"A": "Não.", "B": "Sim, um.", "C": "Sim, dois.", "D": "Sim, três.", "E": "Sim, quatro ou mais."})

# %%
df_visualizacaoQ8 = df.groupby(by=['Q008']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ8

# %%
df.Q009 = df.Q009.replace({"A": "Não.", "B": "Sim, um.", "C": "Sim, dois.", "D": "Sim, três.", "E": "Sim, quatro ou mais."})

# %%
df_visualizacaoQ9 = df.groupby(by=['Q009']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ9

# %%
df.Q010 = df.Q010.replace({"A": "Não.", "B": "Sim, um.", "C": "Sim, dois.", "D": "Sim, três.", "E": "Sim, quatro ou mais."})

# %%
df_visualizacaoQ10 = df.groupby(by=['Q010']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ10

# %%
df.Q011 = df.Q011.replace({"A": "Não.", "B": "Sim, um.", "C": "Sim, dois.", "D": "Sim, três.", "E": "Sim, quatro ou mais."})

# %%
df_visualizacaoQ11 = df.groupby(by=['Q011']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ11

# %%
df.Q012 = df.Q012.replace({"A": "Não.", "B": "Sim, um.", "C": "Sim, dois.", "D": "Sim, três.", "E": "Sim, quatro ou mais."})

# %%
df_visualizacaoQ12 = df.groupby(by=['Q012']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ12

# %%
df.Q013 = df.Q013.replace({"A": "Não.", "B": "Sim, um.", "C": "Sim, dois.", "D": "Sim, três.", "E": "Sim, quatro ou mais."})

# %%
df_visualizacaoQ13 = df.groupby(by=['Q013']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ13

# %%
df.Q014 = df.Q014.replace({"A": "Não.", "B": "Sim, um.", "C": "Sim, dois.", "D": "Sim, três.", "E": "Sim, quatro ou mais."})

# %%
df_visualizacaoQ14 = df.groupby(by=['Q014']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ14

# %%
df.Q015 = df.Q015.replace({"A": "Não.", "B": "Sim, um.", "C": "Sim, dois.", "D": "Sim, três.", "E": "Sim, quatro ou mais."})

# %%
df_visualizacaoQ15 = df.groupby(by=['Q015']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ15

# %%
df.Q016 = df.Q016.replace({"A": "Não.", "B": "Sim, um.", "C": "Sim, dois.", "D": "Sim, três.", "E": "Sim, quatro ou mais."})

# %%
df_visualizacaoQ16 = df.groupby(by=['Q016']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ16

# %%
df.Q017 = df.Q017.replace({"A": "Não.", "B": "Sim, um.", "C": "Sim, dois.", "D": "Sim, três.", "E": "Sim, quatro ou mais."})

# %%
df_visualizacaoQ17 = df.groupby(by=['Q017']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ17

# %%
df.Q018 = df.Q018.replace({"A": "Não.", "B": "Sim, um.", "C": "Sim, dois.", "D": "Sim, três.", "E": "Sim, quatro ou mais."})

# %%
df_visualizacaoQ18 = df.groupby(by=['Q018']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ18

# %%
df.Q019 = df.Q019.replace({"A": "Não.", "B": "Sim, um.", "C": "Sim, dois.", "D": "Sim, três.", "E": "Sim, quatro ou mais."})

# %%
df_visualizacaoQ19 = df.groupby(by=['Q019']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ19

# %%
df.Q020 = df.Q020.replace({"A": "Não.", "B": "Sim, um.", "C": "Sim, dois.", "D": "Sim, três.", "E": "Sim, quatro ou mais."})

# %%
df_visualizacaoQ20 = df.groupby(by=['Q020']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ20

# %%
df.Q021 = df.Q021.replace({"A": "Não.", "B": "Sim, um.", "C": "Sim, dois.", "D": "Sim, três.", "E": "Sim, quatro ou mais."})

# %%
df_visualizacaoQ21 = df.groupby(by=['Q021']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ21

# %%
df.Q022 = df.Q022.replace({"A": "Não.", "B": "Sim, um.", "C": "Sim, dois.", "D": "Sim, três.", "E": "Sim, quatro ou mais."})

# %%
df_visualizacaoQ22 = df.groupby(by=['Q022']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ22

# %%
df.Q023 = df.Q023.replace({"A": "Não.", "B": "Sim, um.", "C": "Sim, dois.", "D": "Sim, três.", "E": "Sim, quatro ou mais."})

# %%
df_visualizacaoQ23 = df.groupby(by=['Q023']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ23

# %%
df.Q024 = df.Q024.replace({"A": "Não.", "B": "Sim, um.", "C": "Sim, dois.", "D": "Sim, três.", "E": "Sim, quatro ou mais."})

# %%
df_visualizacaoQ24 = df.groupby(by=['Q024']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ24

# %%
df.Q025 = df.Q025.replace({"A": "Não.", "B": "Sim."})

# %%
df_visualizacaoQ25 = df.groupby(by=['Q025']).count()['NU_INSCRICAO'].reset_index()
df_visualizacaoQ25

# %%
plt.figure(figsize = (14,6))
gender_count = df.groupby("TP_SEXO").describe()["NU_INSCRICAO"]["count"].reset_index()
sns.barplot(data = gender_count, x = "count", y = "TP_SEXO", orient = "h",);

# %%
plt.figure(figsize = (14,6))
f = sns.distplot(df.NU_IDADE)
df.NU_IDADE.describe()[["min","50%","max"]]

# %%
df = df.dropna()
df["TESTS_GRADE"] = (df["NU_NOTA_CN"] + df["NU_NOTA_CH"] + df["NU_NOTA_LC"] + df["NU_NOTA_MT"])
df.head()

# %%
plt.figure(figsize = (20,30))
mean_grade_by_city = df.groupby("NO_MUNICIPIO_RESIDENCIA").mean()["TESTS_GRADE"].reset_index().sort_values(by="TESTS_GRADE", ascending = False)
sns.barplot(data = mean_grade_by_city, x = "TESTS_GRADE", y = "NO_MUNICIPIO_RESIDENCIA", orient = "h");

# %%
plt.figure(figsize = (14,6))
public_grades = df[df["TP_ESCOLA"] == 2]["TESTS_GRADE"]
private_grades = df[df["TP_ESCOLA"] == 3]["TESTS_GRADE"]
sns.distplot(public_grades, label = "Public");
sns.distplot(private_grades, label = "Private");
plt.legend();

# %%
plt.figure(figsize = (14,6))
mean_internet_grades = df.groupby("Q025").mean()["TESTS_GRADE"].reset_index()
mean_internet_grades["Q025"] = ["NO","YES"]
sns.barplot(data = mean_internet_grades, x ="TESTS_GRADE" , y = "Q025", orient = "h" );

# %%
plt.figure(figsize = (14,6))
mean_grade_by_gender = df.groupby("TP_SEXO").describe()["TESTS_GRADE"]["mean"].reset_index()
sns.barplot(data = mean_grade_by_gender, x = "mean", y = "TP_SEXO", orient = "h",);

# %%
plt.figure(figsize = (14,6))
female_grades = df[df["TP_SEXO"] == "F"]["TESTS_GRADE"]
male_grades = df[df["TP_SEXO"] == "M"]["TESTS_GRADE"]
sns.distplot(female_grades, label = "Female");
sns.distplot(male_grades, label = "Male");
plt.legend();

# %%
plt.figure(figsize = (14,6))
mean_grade_by_race = df.groupby("TP_COR_RACA").mean()["TESTS_GRADE"]
mean_grade_by_race = mean_grade_by_race.rename(index = {0:"Não declarado", 1:"Branca", 2:"Preta",3:"Parda" , 4:"Amarela", 5:"Indigena"}).reset_index()
mean_grade_by_race = mean_grade_by_race[1:].sort_values(by = "TESTS_GRADE", ascending = False)
sns.barplot(data = mean_grade_by_race,x = "TESTS_GRADE" , y = "TP_COR_RACA", orient = "h");

# %%
plt.figure(figsize = (20,10))
mean_graded_by_wealth = df.groupby("Q006").mean()["TESTS_GRADE"].reset_index()
sns.barplot(data = mean_graded_by_wealth, x = "TESTS_GRADE", y = "Q006", orient = "h");

# %%
plt.figure(figsize = (14,6))
mean_grade_by_mom_education = df.groupby("Q001").mean()["TESTS_GRADE"][0:-1].reset_index()
sns.barplot(data = mean_grade_by_mom_education, x = "TESTS_GRADE" , y = "Q001", orient = "h");

# %%
plt.figure(figsize = (14,6))
mean_grade_by_dad_education = df.groupby("Q002").mean()["TESTS_GRADE"][0:-1].reset_index()
sns.barplot(data = mean_grade_by_dad_education, x = "TESTS_GRADE" , y = "Q002", orient = "h");

# %%
plt.figure(figsize = (16,8))
dist_grade_pop_res = df.groupby("Q005").describe()["NU_INSCRICAO"]["count"]
mean_grade_by_pop_res = df.groupby("Q005").mean()["TESTS_GRADE"].reset_index().iloc[0:7]
sns.barplot(data = mean_grade_by_pop_res, x = "TESTS_GRADE", y = "Q005", orient = "h");
dist_grade_pop_res

# %%
plt.figure(figsize = (14,6))
mean_grade_by_gender = df.groupby("NO_MUNICIPIO_RESIDENCIA").describe()["TESTS_GRADE"]["mean"].reset_index()
sns.barplot(data = mean_grade_by_gender, x = "mean", y = "NO_MUNICIPIO_RESIDENCIA", orient = "h",);
